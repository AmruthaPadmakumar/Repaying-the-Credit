# %%
import matplotlib.pyplot as plt             
from tabulate import tabulate               
import matplotlib as mat                     
import seaborn as sns                       
import pandas as pd                         
import numpy as np

# %% [markdown]
# ## Level 0: Understanding data

# %%
df=pd.read_csv("DS1_C5_S4_Credit_Data_Hackathon.csv")
df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED MOBILE  \
# 0          202500.0    406597.5         351000.0  ...          -637      1
# 1          270000.0   1293502.5        1129500.0  ...         -1188      1
# 2           67500.0    135000.0         135000.0  ...          -225      1
# 3          135000.0    312682.5         297000.0  ...         -3039      1
# 4          121500.0    513000.0         513000.0  ...         -3038      1
#
#   WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  OCCUPATION_TYPE  \
# ...

# %%
df.tail()
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
#        AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED  \
# 99995          157500.0    755190.0         675000.0  ...          -232
# 99996          225000.0    284400.0         225000.0  ...          -182
# 99997          135000.0   1262583.0        1102500.0  ...         -4805
# 99998          135000.0    225000.0         225000.0  ...          -340
# 99999          202500.0    337500.0         337500.0  ...         -3230
#
#       MOBILE WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  \
# ...

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SK_ID_CURR           100000 non-null  int64
#  1   TARGET               100000 non-null  int64
#  2   NAME_CONTRACT_TYPE   100000 non-null  object
#  3   GENDER               100000 non-null  object
#  4   Car                  100000 non-null  object
#  5   House                100000 non-null  object
#  6   CNT_CHILDREN         100000 non-null  int64
#  7   AMT_INCOME_TOTAL     100000 non-null  float64
#  8   AMT_CREDIT           100000 non-null  float64
#  9   AMT_GOODS_PRICE      99919 non-null   float64
#  10  NAME_TYPE_SUITE      99595 non-null   object
#  11  NAME_INCOME_TYPE     100000 non-null  object
#  12  NAME_EDUCATION_TYPE  100000 non-null  object
#  13  NAME_FAMILY_STATUS   100000 non-null  object
#  14  DAYS_EMPLOYED        100000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %% [markdown]
# ## Level 1: Analysis

# %%
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:               
        if df[column].nunique() < 100:      
                                                    
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         

from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical          continuous
# -------------------  ----------------
# TARGET               SK_ID_CURR
# NAME_CONTRACT_TYPE   AMT_INCOME_TOTAL
# GENDER               AMT_CREDIT
# Car                  AMT_GOODS_PRICE
# House                DAYS_EMPLOYED
# CNT_CHILDREN
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# MOBILE
# WORK_PHONE
# HOME_PHONE
# MOBILE_REACHABLE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# APPLICATION_DAY
# TOTAL_DOC_SUBMITTED

# %% [markdown]
# ### Univariate analysis of categorical column

# %% [markdown]
# ## Analysis of target column

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") 
    print(f"Mode of {col} is {df[col].mode()[0]}")  
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}")

# %%
info_of_cat("TARGET")
# Out:
# Unique values in TARGET are: [1 0]
# Mode of TARGET is 0
# Number of missing values in TARGET is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of Target")                  
percentage = df["TARGET"].value_counts()        
labels = list(df["TARGET"].value_counts().index) 

sns.countplot(x = df["TARGET"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### By above graph we can conclude that  8.09% clients are  having payment difficulty

# %% [markdown]
# ### Analysis of NAME_CONTRACT_TYPE column

# %%
info_of_cat("NAME_CONTRACT_TYPE")
# Out:
# Unique values in NAME_CONTRACT_TYPE are: ['Cash loans' 'Revolving loans']
# Mode of NAME_CONTRACT_TYPE is Cash loans
# Number of missing values in NAME_CONTRACT_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title(" count of NAME_CONTRACT_TYPE")                  
percentage = df["NAME_CONTRACT_TYPE"].value_counts()        
labels = list(df["NAME_CONTRACT_TYPE"].value_counts().index) 

sns.countplot(x = df["NAME_CONTRACT_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### By above graph we can conclude that there are more number of Cashloans

# %% [markdown]
# ### Analysis of gender column

# %%
info_of_cat("GENDER")
# Out:
# Unique values in GENDER are: ['M' 'F' 'XNA']
# Mode of GENDER is F
# Number of missing values in GENDER is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title(" count of Gender")                  
percentage = df["GENDER"].value_counts()        
labels = list(df["GENDER"].value_counts().index) 

sns.countplot(x = df["GENDER"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### By above graph we can conclude that the clients mostly are Female

# %% [markdown]
# ### Analysis of CNT_CHILDREN column

# %%
info_of_cat("CNT_CHILDREN")
# Out:
# Unique values in CNT_CHILDREN are: [ 0  1  2  3  4  7  5  6  8  9 11 12]
# Mode of CNT_CHILDREN is 0
# Number of missing values in CNT_CHILDREN is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title(" count of client children")                  
percentage = df["CNT_CHILDREN"].value_counts()        
labels = list(df["CNT_CHILDREN"].value_counts().index) 

sns.countplot(x = df["CNT_CHILDREN"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### By above graph we can conclude that most of the clients have no children.

# %% [markdown]
# ### Analysis of NAME_INCOME_TYPE column

# %%
info_of_cat("NAME_INCOME_TYPE")
# Out:
# Unique values in NAME_INCOME_TYPE are: ['Working' 'State servant' 'Commercial associate' 'Pensioner' 'Unemployed'
#  'Student' 'Businessman' 'Maternity leave']
# Mode of NAME_INCOME_TYPE is Working
# Number of missing values in NAME_INCOME_TYPE is 0

# %%
print((df["NAME_INCOME_TYPE"].value_counts()/len(df))*100)               
fig, ax = plt.subplots(figsize = (16, 9))
sns.countplot(x = df[ 'NAME_INCOME_TYPE'], ax = ax)
for bar in ax.patches:                                                  
    percentage = f"{round((bar.get_height() /df.shape[0])*100 , 2)} %"  
                                                                            
    x = bar.get_x() + bar.get_width() /2                                
    y = bar.get_height()                                                
    ax.annotate(percentage, (x, y), va= "bottom", ha = "center" ) 
plt.title('Distribution of Client income type')
plt.show()
# Out:
# Working                 51.902
# Commercial associate    23.217
# Pensioner               17.857
# State servant            7.000
# Unemployed               0.010
# Student                  0.009
# Businessman              0.004
# Maternity leave          0.001
# Name: NAME_INCOME_TYPE, dtype: float64

# %% [markdown]
# ### By observing above graph we can say that most of the clients have income type as working.

# %% [markdown]
# ### Analysis of NAME_EDUCATION_TYPE column

# %%
info_of_cat("NAME_EDUCATION_TYPE")
# Out:
# Unique values in NAME_EDUCATION_TYPE are: ['Secondary / secondary special' 'Higher education' 'Incomplete higher'
#  'Lower secondary' 'Academic degree']
# Mode of NAME_EDUCATION_TYPE is Secondary / secondary special
# Number of missing values in NAME_EDUCATION_TYPE is 0

# %%
print((df["NAME_EDUCATION_TYPE"].value_counts()/len(df))*100)               
fig, ax = plt.subplots(figsize = (16, 9))
sns.countplot(x = df[ 'NAME_EDUCATION_TYPE'], ax = ax)
for bar in ax.patches:                                                  
    percentage = f"{round((bar.get_height() /df.shape[0])*100 , 2)} %"  
                                                                            
    x = bar.get_x() + bar.get_width() /2                                
    y = bar.get_height()                                                
    ax.annotate(percentage, (x, y), va= "bottom", ha = "center" ) 
plt.title('Distribution of Client education type')
plt.show()
# Out:
# Secondary / secondary special    71.068
# Higher education                 24.399
# Incomplete higher                 3.270
# Lower secondary                   1.214
# Academic degree                   0.049
# Name: NAME_EDUCATION_TYPE, dtype: float64

# %% [markdown]
# ### By observing above graph we can say that most of the clients have education type as secondary/secondary education.

# %% [markdown]
# ### Analysis of MOBILE column

# %%
info_of_cat("MOBILE")
# Out:
# Unique values in MOBILE are: [1 0]
# Mode of MOBILE is 1
# Number of missing values in MOBILE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title(" count of client providing mobile")                  
percentage = df["MOBILE"].value_counts()        
labels = list(df["MOBILE"].value_counts().index) 

sns.countplot(x = df["MOBILE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### All the clients have provided their mobile number

# %% [markdown]
# ### Analysis of HOME_PHONE  column

# %%
info_of_cat("HOME_PHONE")
# Out:
# Unique values in HOME_PHONE are: [0 1]
# Mode of HOME_PHONE is 0
# Number of missing values in HOME_PHONE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title(" count of client providing home phone")                  
percentage = df["HOME_PHONE"].value_counts()        
labels = list(df["HOME_PHONE"].value_counts().index) 
ax[1].set_title(" percentage of client providing home phone")
sns.countplot(x = df["HOME_PHONE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### By observing above graph we can conclude that most of the clients have not provided their home phone.

# %% [markdown]
# ### Analysis of MOBILE_REACHABLE column

# %%
info_of_cat("MOBILE_REACHABLE")
# Out:
# Unique values in MOBILE_REACHABLE are: [1 0]
# Mode of MOBILE_REACHABLE is 1
# Number of missing values in MOBILE_REACHABLE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title(" count of client whose mobile phone are reachable")                  
percentage = df["MOBILE_REACHABLE"].value_counts()        
labels = list(df["MOBILE_REACHABLE"].value_counts().index) 

sns.countplot(x = df["MOBILE_REACHABLE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Most of the clients mobile phone are reachable

# %% [markdown]
# ### Analysis of OCCUPATION_TYPE

# %%
info_of_cat("OCCUPATION_TYPE")
# Out:
# Unique values in OCCUPATION_TYPE are: ['Laborers' 'Core staff' 'Accountants' 'Managers' nan 'Drivers'
#  'Sales staff' 'Cleaning staff' 'Cooking staff' 'Private service staff'
#  'Medicine staff' 'Security staff' 'High skill tech staff'
#  'Waiters/barmen staff' 'Low-skill Laborers' 'Realty agents' 'Secretaries'
#  'IT staff' 'HR staff']
# Mode of OCCUPATION_TYPE is Laborers
# Number of missing values in OCCUPATION_TYPE is 31224

# %%
# Replacing missing value by mode
occupation_type_mode = df.OCCUPATION_TYPE.mode()[0]
df["OCCUPATION_TYPE"].fillna(occupation_type_mode, inplace = True)

# %%
fig, ax = plt.subplots(figsize= (16, 9))
ax = sns.countplot(x = df["OCCUPATION_TYPE"])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha = "right")  
count = len(df["OCCUPATION_TYPE"])                                     
for bar in ax.patches:                                                  
    percentage = f"{round(bar.get_height()/count, 2)*100} %"           
                                                                               
    x = bar.get_x() + bar.get_width() /2                                
    y = bar.get_height()                                                
    ax.annotate(percentage, (x, y), ha = "center", va = "top")          
plt.title('Distribution of Clients occupation type')                                                                       
plt.show()

# %% [markdown]
# ### By observing above graph we can conclude that most of the clients have their occupation type as Laborers.

# %% [markdown]
# ### Analysis of TOTAL_DOC_SUBMITTED column

# %%
info_of_cat("TOTAL_DOC_SUBMITTED")
# Out:
# Unique values in TOTAL_DOC_SUBMITTED are: [1 0 2 3 4]
# Mode of TOTAL_DOC_SUBMITTED is 1
# Number of missing values in TOTAL_DOC_SUBMITTED is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title(" count of client that have sumbitted total document")                  
percentage = df["TOTAL_DOC_SUBMITTED"].value_counts()        
labels = list(df["TOTAL_DOC_SUBMITTED"].value_counts().index) 

sns.countplot(x = df["TOTAL_DOC_SUBMITTED"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Most of the clients have submitted one document

# %% [markdown]
# ##  Univeriate analysis of continuous column

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %% [markdown]
# ### Analysis of AMT_INCOME_TOTAL

# %%
info_of_numerical("AMT_INCOME_TOTAL")
# Out:
# The mean of the AMT_INCOME_TOTAL is 169426.07027325002
# The median of the AMT_INCOME_TOTAL is 144000.0
# The mode of the AMT_INCOME_TOTAL is 135000.0
# The standard deviation of the AMT_INCOME_TOTAL is 383500.74427718896
# Number of missing values in the AMT_INCOME_TOTAL is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))              
sns.histplot(x = df["AMT_INCOME_TOTAL"], ax =ax[1], color = "r") 
sns.boxplot(x = df["AMT_INCOME_TOTAL"], ax = ax[0], color = "g") 
plt.title("Distribution of AMT_INCOME_TOTAL")
plt.show()

# %% [markdown]
# ### There are outliers in data so we need to perform outlier analysis

# %%
Q1=df['AMT_INCOME_TOTAL'].quantile(0.25)
Q3=df['AMT_INCOME_TOTAL'].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

df.loc[(df['AMT_INCOME_TOTAL']<lower_bound) | (df['AMT_INCOME_TOTAL']>upper_bound), 'AMT_INCOME_TOTAL']=np.nan

clean_value=df[(df['AMT_INCOME_TOTAL'].notnull())]['AMT_INCOME_TOTAL']
df['AMT_INCOME_TOTAL'].fillna(clean_value,inplace=True)

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))              
sns.histplot(x = df["AMT_INCOME_TOTAL"], ax =ax[1], color = "r") 
sns.boxplot(x = df["AMT_INCOME_TOTAL"], ax = ax[0], color = "g") 
plt.title("Distribution of AMT_INCOME_TOTAL")
plt.show()

# %% [markdown]
# ### By observing above graph we can conclude that most of the clients have income ranging between 100000 to 150000

# %% [markdown]
# ### Analysis of AMT_CREDIT column

# %%
info_of_numerical("AMT_CREDIT")
# Out:
# The mean of the AMT_CREDIT is 599003.4465
# The median of the AMT_CREDIT is 513040.5
# The mode of the AMT_CREDIT is 450000.0
# The standard deviation of the AMT_CREDIT is 402051.9591213264
# Number of missing values in the AMT_CREDIT is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))              
sns.histplot(x = df["AMT_CREDIT"], ax =ax[1], color = "r") 
sns.boxplot(x = df["AMT_CREDIT"], ax = ax[0], color = "g") 
plt.title("Distribution of AMT_CREDIT")
plt.show()

# %% [markdown]
# ### There are outliers in data so we need to perform outlier analysis

# %%
Q1=df['AMT_CREDIT'].quantile(0.25)
Q3=df["AMT_CREDIT"].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

df.loc[(df['AMT_CREDIT']<lower_bound) | (df['AMT_CREDIT']>upper_bound), 'AMT_CREDIT']=np.nan

clean_value=df[(df['AMT_CREDIT'].notnull())]['AMT_CREDIT']
df['AMT_CREDIT'].fillna(clean_value,inplace=True)

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))              
sns.histplot(x = df["AMT_CREDIT"], ax =ax[1], color = "r") 
sns.boxplot(x = df["AMT_CREDIT"], ax = ax[0], color = "g") 
plt.title("Distribution of AMT_CREDIT")
plt.show()

# %% [markdown]
# ### Most of the clients credit amount lies between 0.2 to 0.5

# %% [markdown]
# ### Analysis of DAYS_EMPLOYED

# %%
info_of_numerical("DAYS_EMPLOYED")
# Out:
# The mean of the DAYS_EMPLOYED is 63292.22206
# The median of the DAYS_EMPLOYED is -1219.0
# The mode of the DAYS_EMPLOYED is 365243
# The standard deviation of the DAYS_EMPLOYED is 140839.69729599176
# Number of missing values in the DAYS_EMPLOYED is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))              
sns.histplot(x = df["DAYS_EMPLOYED"], ax =ax[1], color = "r") 
sns.boxplot(x = df["DAYS_EMPLOYED"], ax = ax[0], color = "g") 
plt.title("Distribution of DAYS_EMPLOYED")
plt.show()

# %%
Q1=df['DAYS_EMPLOYED'].quantile(0.25)
Q3=df["DAYS_EMPLOYED"].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

df.loc[(df['DAYS_EMPLOYED']<lower_bound) | (df["DAYS_EMPLOYED"]>upper_bound), 'DAYS_EMPLOYED']=np.nan

clean_value=df[(df['DAYS_EMPLOYED'].notnull())]['DAYS_EMPLOYED']
df['DAYS_EMPLOYED'].fillna(clean_value,inplace=True)

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))              
sns.histplot(x = df["DAYS_EMPLOYED"], ax =ax[1], color = "r") 
sns.boxplot(x = df["DAYS_EMPLOYED"], ax = ax[0], color = "g") 
plt.title("Distribution of DAYS_EMPLOYED")
plt.show()

# %% [markdown]
# ### this is the graph we get after removing outliers

# %% [markdown]
# ## Level 2. Analysis

# %% [markdown]
# ## Categorical to Categorical

# %% [markdown]
# ## Relationship between Target and gender

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "GENDER", hue = "TARGET", data = df)
plt.title("Relationship between target and gender")
plt.show()

# %% [markdown]
# ### By above graph we can conclude that female category have more number of clients that have difficulty in payment.

# %% [markdown]
# ## Relationship between target and NAME_CONTRACT_TYPE

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "NAME_CONTRACT_TYPE", hue = "TARGET", data = df)
plt.title("Relationship between target and name_contract_type")
plt.show()

# %% [markdown]
# ### By above graph we can conclude that in category cash loans there are more number of clients that have difficulty in payment.

# %% [markdown]
# ## Relationship between Target and CNT_CHILDREN

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "CNT_CHILDREN", hue = "TARGET", data = df)
plt.title("Relationship between target and CNT_CHILDREN")
plt.show()

# %% [markdown]
# ### By above graph we can conclude that clients that donot have children are more likely to be the clients that have difficulty in payment.

# %% [markdown]
# ### Relationship between target and NAME_INCOME_TYPE

# %%
fig, ax = plt.subplots(figsize = (16, 7))
sns.countplot(x = "NAME_INCOME_TYPE", hue = "TARGET", data = df)
plt.title("Relationship between target and NAME_INCOME_TYPE")
plt.show()

# %% [markdown]
# ### By observing above graph we can say that clients who have their income type as working are more likely to have difficulty in payment

# %% [markdown]
# ## Relationship between target and NAME_EDUCATION_TYPE

# %%
fig, ax = plt.subplots(figsize = (13, 7))
sns.countplot(x = "NAME_EDUCATION_TYPE", hue = "TARGET", data = df)
plt.title("Relationship between target and NAME_EDUCATION_TYPE")
plt.show()

# %% [markdown]
# ### By above graph we can conclude that secondary/secondary special education types have more number of people with payment difficulties.

# %% [markdown]
# ### Relationship between target and MOBILE_REACHABLE

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "MOBILE_REACHABLE", hue = "TARGET", data = df)
plt.title("Relationship between target andMOBILE_REACHABLE")
plt.show()

# %% [markdown]
# ### By above graph we can conclude that most of the client who have difficulty in payment have their mobile reachable.

# %% [markdown]
# ### Relationship between target and OCCUPATION_TYPE column

# %%
fig, ax = plt.subplots(figsize = (16, 9))
sns.countplot(x = "OCCUPATION_TYPE", hue = "TARGET", data = df)
plt.title("Relationship between target and OCCUPATION_TYPE ")
plt.show()

# %% [markdown]
# ### By above graph we can conclude that clients whose occupation type is Laborers have difficulty in payment.

# %% [markdown]
# ### Relationship between target and TOTAL_DOC_SUBMITTED

# %%
fig, ax = plt.subplots(figsize = (16, 9))
sns.countplot(x = "TOTAL_DOC_SUBMITTED", hue = "TARGET", data = df)
plt.title("Relationship between target and TOTAL_DOC_SUBMITTED ")
plt.show()

# %% [markdown]
# ### By observing above graph we can conclude that clients who have submitted 1 document have difficulty in payment.

# %% [markdown]
# ## Categorical to continuous

# %% [markdown]
# ### Relationship between target and AMT_INCOME_TOTAL

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["AMT_INCOME_TOTAL"], hue = df["TARGET"], ax = ax[0])
sns.boxplot(y = df["AMT_INCOME_TOTAL"] ,x = df["TARGET"] , ax = ax[1])
plt.title("Relationship between target and  AMT_INCOME_TOTAL")
plt.show()

# %% [markdown]
# ### By above graph we can conclude that client having income ranging between 100000 to 200000 has payment difficulty.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### By the analysis we can conclude that the female clients with cash loans, those who have 1 children, Income type as Working, education type as Secondary/secondary special , occupation type as labourers, document submitted is only one and their amount  income ranging between 100000 to 200000 are more likely to become defaulters.
#
# ### By considering these factors and carefully evaluating them the firm can identify customers that have lower probability of becoming a defaulter and can make decisions during loan approval process.
